# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,6,8,10]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,6,8,10]
plt.title("Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
y1=[]
y2=[]
x=range(-100,100,10)
for i in x:
    y1.append(i**2)
for i in x:
    y2.append(-i**2)
plt.plot(x,y1)
plt.plot(x,y2)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('simple graph ')
plt.axhline()
plt.axvline()
plt.show()

# %%
x = range(-100,100,10)
for i in x:
    y1.append(i**2)
for i in x:
    y2.append(-i**2)
y1 = []
y2 = []
for i in x:
    y1.append(i**2)
for i in x:
    y2.append(-i**2)
plt.plot(x, y1, color='green')
plt.plot(x,y2,color='Maroon')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Simple Graph')
plt.axhline(color='red')
plt.axvline(color='green')
plt.grid(True)
plt.show()

# %%
x = range(-100,100,10)
for i in x:
    y1.append(i**2)
for i in x:
    y2.append(-i**2)
y1 = []
y2 = []
for i in x:
    y1.append(i**2)
for i in x:
    y2.append(-i**2)
plt.plot(x, y1, color='green')
plt.plot(x,y2,color='Maroon')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Simple Graph')
plt.axhline(color='red')
plt.axvline(color='green')
plt.savefig("linegraph.jpg")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("temporal.csv")
plt.plot(df['deep learning'],df['machine learning'],color='red')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('line plot')
plt.savefig("tempo.jpg")
plt.show()

# %%
plt.plot(df['Mes'],df['data science'],label='data science')
plt.plot(df['Mes'],df['machine learning'],label='machine learning')
plt.plot(df['Mes'],df['deep learning'],label='deep learning')
plt.xlabel('Date')
plt.ylabel('Popularity')
plt.title('Popularity of AI terms by date')
plt.grid(True)
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
plt.plot(df['deep learning'],df['machine learning'],color='red')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('line plot')
plt.xlim(10, 100)
plt.ylim(0, 50)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
x_values = [0,1, 2, 3, 4, 5]
y_values = [0, 1, 4, 9, 16, 25]
plt.scatter(x_values, y_values,color="blue")
plt.title("Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
plt.plot(df['deep learning'],df['machine learning'],color='red',marker='^')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('scatter plot')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
plt.plot(df['deep learning'],df['machine learning'],color='red',marker='*')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('scatter plot')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
values = [5,6,3,7,2]
names = ['A','B','C','D','E']
plt.bar(names, values,color="red")
plt.title("Bar Graph")
plt.xlabel("Names")
plt.ylabel("Values")
plt.show()

# %%
import matplotlib.pyplot as plt
values = [5,6,3,7,2]
names = ['A','B','C','D','E']
plt.barh(names, values,color="red")
plt.title("Bar Graph")
plt.xlabel("Names")
plt.ylabel("Values")
plt.show()

# %%
import matplotlib.pyplot as plt
values = [5,6,3,7,2]
names = ['A','B','C','D','E']
c1 = ['red','green']
c2 = ['b','g','y']
plt.bar(names,values,width=0.5,color=c1)
plt.show()
plt.barh(names,values,height=0.5,color=c2)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("temporal.csv")
plt.bar(df['deep learning'],df['machine learning'],color='red')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('Bar graph')
plt.show()

# %%
import seaborn as sns
import pandas as pd
df = pd.read_csv("temporal.csv")
sns.lineplot(x="data science", y="machine learning", data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = sns.load_dataset("iris")
sns.lineplot(x="sepal_length", y="sepal_width",  data=data)
sns.set_style("whitegrid")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = sns.load_dataset("iris")
sns.lineplot(x="sepal_length", y="sepal_width",  data=data)
sns.set_style("darkgrid")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = sns.load_dataset("iris")
sns.lineplot(x="sepal_length", y="sepal_width",  data=data)
sns.despine(left=True,right=False)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("tips.csv")
sns.countplot(x="sex", hue='day',data=df,palette="Set1")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("Iris.csv")
sns.countplot(x="Species",data=df,palette="Set1")
plt.show()
# Out:
# C:\Users\RITHWIK\AppData\Local\Temp\ipykernel_14932\3201764246.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Species",data=df,palette="Set1")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = sns.load_dataset("tips")
sns.pairplot(data,hue="day")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = sns.load_dataset("iris")
sns.pairplot(data,hue="species")
plt.show()

# %%
import seaborn as sns
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x)
sns.kdeplot(y)
# Out:
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x,shade=True)
sns.kdeplot(y)
# Out:
# C:\Users\RITHWIK\AppData\Local\Temp\ipykernel_14932\1388057297.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x,shade=True)
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x=x,y=y)
# Out:
# <Axes: >

# %%
import seaborn as sns
df=sns.load_dataset("iris")
sns.kdeplot(x=df['petal_length'])
sns.kdeplot(x=df['petal_width'],shade=True)
# Out:
# C:\Users\RITHWIK\AppData\Local\Temp\ipykernel_14932\2391516832.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df['petal_width'],shade=True)
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
import seaborn as sns
data = sns.load_dataset("tips")
sns.boxplot(data['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
import matplotlib.pyplot as plt
data = [12,15,20,20,22,23,25,25,30,32,35,40]
plt.hist(data,bins=5,color='skyblue',edgecolor='black')
plt.title("Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()
